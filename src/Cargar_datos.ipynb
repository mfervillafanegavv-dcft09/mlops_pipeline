# %% [markdown]
# # Carga de datos
#
# En este notebook se realiza la carga inicial del dataset utilizado para el proyecto de predicción de churn de clientes.
#
# El objetivo es verificar la correcta lectura de los datos, conocer sus dimensiones, identificar las variables disponibles y realizar controles iniciales de calidad antes de comenzar el análisis exploratorio.

# %%
import pandas as pd

# %%
#Guarda esa tabla en una variable llamada df
df = pd.read_csv("../Base_de_datos.csv")
#Mostrar las 5 primeras filas
df.head()

# %% [markdown]
# ## Exploración inicial del dataset
#
# A continuación se realiza una revisión general del conjunto de datos para conocer sus dimensiones, variables, tipos de datos y calidad inicial.

# %%
#Filas y columnas del dataset
df.shape
# Out:
# (5000, 15)

# %%
#Nombre de todas las variables/columnas
df.columns

# %%
#Cantidad de registros, nombre de columnas, valores nulos, tipos de  datos
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         5000 non-null   str
#  1   signup_month        5000 non-null   int64
#  2   age                 5000 non-null   int64
#  3   tenure_months       5000 non-null   int64
#  4   region              5000 non-null   str
#  5   channel             5000 non-null   str
#  6   plan                5000 non-null   str
#  7   sessions_week       5000 non-null   int64
#  8   avg_session_min     5000 non-null   float64
#  9   notif_click_rate    5000 non-null   float64
#  10  support_tickets_3m  5000 non-null   int64
#  11  discount_pct_3m     5000 non-null   float64
#  12  late_payments_6m    5000 non-null   int64
#  13  auto_renew          5000 non-null   int64
#  14  churn               5000 non-null   int64
# dtypes: float64(3), int64(8), str(4)
# memory usage: 586.1 KB

# %% [markdown]
# Calidad de los datos

# %%
# Suma los nulos de cada una de las columnas
df.isnull().sum()
# Out:
# customer_id           0
# signup_month          0
# age                   0
# tenure_months         0
# region                0
# channel               0
# plan                  0
# sessions_week         0
# avg_session_min       0
# notif_click_rate      0
# support_tickets_3m    0
# discount_pct_3m       0
# late_payments_6m      0
# auto_renew            0
# churn                 0
# dtype: int64

# %%
# Suma los duplicados de cada una de las columnas
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Conclusiones de la carga inicial
#
# El dataset contiene 5.000 registros y 15 variables relacionadas con características de los clientes, su comportamiento de uso y su permanencia en el servicio.
#
# Durante la revisión inicial se verificó que:
#
# - El dataset se cargó correctamente.
# - No se identificaron valores nulos.
# - No se encontraron registros duplicados.
# - Se verificaron los nombres y tipos de datos de las variables.
#
# A partir de estas comprobaciones iniciales, el dataset se encuentra preparado para continuar con la etapa de comprensión y análisis exploratorio de datos (EDA).
